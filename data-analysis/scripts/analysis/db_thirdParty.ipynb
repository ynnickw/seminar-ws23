# %% [markdown]
# ## Collect Data

# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Requests to third parties

# %%
conn = sqlite3.connect('../third_party_analysis.db')
cursor = conn.cursor()

query = 'SELECT domain, COUNT(*) FROM domain_counts GROUP BY domain ORDER BY COUNT(*) DESC'

cursor.execute(query)

data1 = cursor.fetchall()
print("Total 3rd party domains: " + str(len(data1)) + "\n")
print("Domain\tCount")
print("----------------------------")
for domain, count in data1:
    print(f"{count}\t{domain}")

conn.close()
# Out:
# Total 3rd party domains: 537
#
# Domain	Count
# ----------------------------
# 1922	media-amazon.com
# 1655	doubleclick.net
# 1332	googlesyndication.com
# 969	adsafeprotected.com
# 955	google.com
# 666	ztat.net
# 666	adobedtm.com
# 602	asadcdn.com
# 597	ssl-images-amazon.com
# 547	google-analytics.com
# 546	guim.co.uk
# 442	adnxs.com
# 424	rubiconproject.com
# 394	amazon-adsystem.com
# 353	gstatic.com
# 317	googletagmanager.com
# 313	criteo.com
# 311	outbrain.com
# 285	taboola.com
# 284	adform.net
# 244	2mdn.net
# 242	google.de
# 238	googletagservices.com
# 229	idcdn.de
# 228	creativecdn.com
# 223	teads.tv
# 216	facebook.com
# 208	cookielaw.org
# 197	aboutyou.cloud
# 193	smartadserver.com
# 191	cloudfront.net
# 187	pinterest.com
# 184	googleapis.com
# 178	tiktok.com
# 173	pubmatic.com
# 173	casalemedia.com
# 164	ctfassets.net
# 163	cxense.com
# 158	bounceexchange.com
# 153	snapchat.com
# 145	yieldlab.net
# 145	chartbeat.net
# 143	ioam.de
# 137	googleadservices.com
# 137	abtasty.com
# 136	glomex.com
# 135	xplosion.de
# 134	cnn.io
# 133	salesforce.com
# 132	otto.de
# 126	presage.io
# 121	bing.com
# 119	dwcdn.net
# 115	optimizely.com
# 112	criteo.net
# 110	privacy-mgmt.com
# 109	piano.io
# 107	permutive.com
# 106	openx.net
# 106	bildstatic.de
# 104	tinypass.com
# 104	ampproject.org
# 102	sprinklr.com
# 101	moatads.com
# 101	doubleverify.com
# 100	adspirit.de
# 98	facebook.net
# 96	mmsrg.com
# 95	trustarc.com
# 92	yahoo.com
# 90	omnitagjs.com
# 90	k5a.io
# 90	amazon.com
# 89	go-mpulse.net
# 87	adsrvr.org
# 84	usercentrics.eu
# 83	google.ru
# 82	mmst.eu
# 82	dianomi.com
# 82	cleverpush.com
# 80	tiqcdn.com
# 80	opencmp.net
# 79	the-ozone-project.com
# 79	cloudflare.com
# 78	demdex.net
# 77	linkedin.com
# 77	bouncex.net
# 76	forter.com
# 74	bidswitch.net
# 73	chartbeat.com
# 71	nr-data.net
# 69	pinimg.com
# 68	youtube.com
# 65	thgim.com
# 65	nuance.com
# 65	adn.cloud
# 64	emsservice.de
# 62	seenthis.se
# 61	opecloud.com
# 60	newrelic.com
# 60	hs-data.com
# 60	ad-production-stage.com
# 59	pbstck.com
# 58	twitter.com
# 58	t.co
# 57	ad4m.at
# 55	petametrics.com
# 54	quantummetric.com
# 53	360yield.com
# 52	cdntrf.com
# 52	akstat.io
# 51	clicktale.net
# 49	confiant-integrations.net
# 49	bluekai.com
# 48	adition.com
# 47	everesttech.net
# 46	adrtx.net
# 44	guardianapps.co.uk
# 42	clarity.ms
# 42	admob.com
# 41	scorecardresearch.com
# 41	medallia.com
# 40	zeotap.com
# 39	pinpoll.com
# 39	id5-sync.com
# 37	wzrkt.com
# 37	kameleoon.io
# 37	amazonaws.com
# 37	ads-twitter.com
# 37	3lift.com
# 36	moengage.com
# 35	geoedge.be
# 35	arkoselabs.com
# 35	aniview.com
# 35	adyen.com
# 34	zalando.com
# 33	force.com
# 33	eyeota.net
# 33	clarium.io
# 32	nmrodam.com
# 32	guardianapis.com
# 32	cquotient.com
# 31	seedtag.com
# 30	sentry.io
# 30	salesforceliveagent.com
# 30	indexww.com
# 29	zemanta.com
# 29	stickyadstv.com
# 29	sitelabweb.com
# 29	adventori.com
# 28	tagcommander.com
# 28	sharethrough.com
# 28	s-onetag.com
# 28	pa-cd.com
# 28	onetag-sys.com
# 28	nikecdn.com
# 28	adnami.io
# 27	sc-static.net
# 27	hmgroup.com
# 26	semasio.net
# 26	rlcdn.com
# 26	online-metrix.net
# 26	dwin1.com
# 26	agma-analytics.de
# 25	visx.net
# 25	lijit.com
# 25	justpremium.com
# 25	dotmetrics.net
# 25	bluecore.com
# 25	bidr.io
# 24	jsdelivr.net
# 24	connectad.io
# 24	akamaihd.net
# 23	target2sell.com
# 23	beusable.net
# 22	user.id
# 22	media.net
# 21	rfihub.com
# 21	quantserve.com
# 21	outbrainimg.com
# 21	nikecloud.com
# 21	everviz.com
# 21	emetriq.de
# 21	bazaarvoice.com
# 20	nmgassets.com
# 20	ml314.com
# 20	licdn.com
# 20	h-cdn.com
# 20	einfach-tasty.de
# 20	brandmetrics.com
# 19	vidazoo.com
# 19	turner.com
# 19	techlab-cdn.com
# 19	signifyd.com
# 19	inq.com
# 19	adalliance.io
# 18	turn.com
# 18	rezync.com
# 18	dspx.tv
# 17	smartclip.net
# 17	site24x7rum.in
# 17	simpli.fi
# 17	ippen.space
# 17	fwcdn3.com
# 17	adup-tech.com
# 16	usabilla.com
# 16	recaptcha.net
# 16	oktacdn.com
# 16	cxpublic.com
# 16	boomtrain.com
# 15	ytimg.com
# 15	technical-service.net
# 15	imgix.net
# 15	glomex.cloud
# 15	f11-ads.com
# 15	ensighten.com
# 15	commander1.com
# 14	typekit.net
# 14	captcha-delivery.com
# 14	bannerflow.net
# 14	aticdn.net
# 14	1rx.io
# 13	scarabresearch.com
# 13	sascdn.com
# 13	kameleoon.eu
# 12	yieldmo.com
# 12	wknd.ai
# 12	purelocalmedia.de
# 12	podigee-cdn.net
# 12	jwpsrv.com
# 12	jwpltx.com
# 12	jwplatform.com
# 12	gumgum.com
# 12	braze.eu
# 11	wunderkind.co
# 11	vi-serve.com
# 11	nmgplatform.com
# 11	instana.io
# 11	exelator.com
# 10	zalan.do
# 10	tremorhub.com
# 10	singular.net
# 10	redintelligence.net
# 10	quora.com
# 10	prreqcroab.icu
# 10	postrelease.com
# 10	omtrdc.net
# 10	loopme.me
# 10	landtiere.de
# 10	kampyle.com
# 10	highcharts.com
# 10	fireworkapi1.com
# 10	exactag.com
# 10	dynatrace.com
# 10	crwdcntrl.net
# 10	contextweb.com
# 10	cloudflareinsights.com
# 10	browsiprod.com
# 10	atonato.de
# 10	ati-host.net
# 10	agkn.com
# 10	adotmob.com
# 10	24garten.de
# 9	upsellit.com
# 9	unrulymedia.com
# 9	ugdturner.com
# 9	trustcommander.net
# 9	stackadapt.com
# 9	soreto.com
# 9	richaudience.com
# 9	quantcount.com
# 9	onetrust.com
# 9	mathtag.com
# 9	jivox.com
# 9	imrworldwide.com
# 9	flashtalking.com
# 9	fastclick.net
# 9	cdnbasket.net
# 9	bluecore.app
# 9	a-mo.net
# 8	undertone.com
# 8	serving-sys.com
# 8	rvty.net
# 8	res-x.com
# 8	mycliplister.com
# 8	mediarithmics.com
# 8	jquery.com
# 8	impactcdn.com
# 8	dotomi.com
# 8	datadome.co
# 8	admanmedia.com
# 8	33across.com
# 7	w55c.net
# 7	video-cdn.net
# 7	truste.com
# 7	tapad.com
# 7	rundsp.com
# 7	roeyecdn.com
# 7	redditstatic.com
# 7	npttech.com
# 7	medialead.de
# 7	krxd.net
# 7	klarnaservices.com
# 7	iqdigital.de
# 7	hlserve.com
# 7	googleusercontent.com
# 7	df-srv.de
# 7	commerce-connector.com
# 7	amplitude.com
# 7	adsafety.net
# 7	adroll.com
# 7	ad-srv.net
# 6	yahoo.net
# 6	welt.de
# 6	vgwort.de
# 6	unpkg.com
# 6	twiago.com
# 6	transmatico.com
# 6	reddit.com
# 6	polyfill.io
# 6	mypass.de
# 6	mitself.net
# 6	mediavine.com
# 6	levexis.com
# 6	klarnacdn.net
# 6	jwpcdn.com
# 6	ivitrack.com
# 6	grapeshot.co.uk
# 6	geolocation-db.com
# 6	fwmrm.net
# 6	fastretailing.com
# 6	emxdgt.com
# 6	deepthought.cloud
# 6	contentsquare.net
# 6	clean.gg
# 6	celtra.com
# 6	capital.de
# 6	btrll.com
# 6	appsflyer.com
# 6	adcell.com
# 6	24vita.de
# 5	zqtk.net
# 5	vtracy.de
# 5	videostep.com
# 5	thebrighttag.com
# 5	smaato.net
# 5	salecycle.com
# 5	revlifter.io
# 5	mookie1.com
# 5	micpn.com
# 5	ipredictive.com
# 5	identityservices.io
# 5	guj.de
# 5	ecomid.com
# 5	cybersource.com
# 5	cwi.re
# 5	connatix.com
# 5	cdn-apple.com
# 5	attn.tv
# 5	advertising.com
# 5	adnxs-simple.com
# 5	adgrx.com
# 5	a2z.com
# 4	zetaglobal.net
# 4	weborama.fr
# 4	tsdtocl.com
# 4	spot.im
# 4	sitescout.com
# 4	sephora-service.com
# 4	rqtrk.eu
# 4	prudsys.com
# 4	plista.com
# 4	payments-amazon.com
# 4	okta.com
# 4	noembed.com
# 4	nativendo.de
# 4	klarna.com
# 4	googleoptimize.com
# 4	fireworkadservices1.com
# 4	eu-1-id5-sync.com
# 4	curalate.com
# 4	cloud.sap
# 4	c-i.as
# 4	azureedge.net
# 4	audrte.com
# 4	algolia.io
# 4	adscale.de
# 4	24books.de
# 3	webgains.io
# 3	vidoomy.com
# 3	trmcdn.eu
# 3	spotxchange.com
# 3	sparwelt.de
# 3	ogury.io
# 3	o2online.de
# 3	ne.jp
# 3	lotto24.de
# 3	liadm.com
# 3	klarnaevt.com
# 3	gobankingrates.com
# 3	fwpixel.com
# 3	fazcdn.net
# 3	creative-serving.com
# 3	cdnwidget.com
# 3	calendly.com
# 3	bttrack.com
# 3	bodygram.com
# 3	behave.com
# 3	azurewebsites.net
# 3	awin1.com
# 3	avads.net
# 3	ariva-services.de
# 3	appspot.com
# 3	amazon.co.uk
# 3	airfrance.fr
# 3	adentifi.com
# 3	4dex.io
# 3	1.1
# 2	wt-safetag.com
# 2	weightwatchers.com
# 2	tribalfusion.com
# 2	tradedoubler.com
# 2	tpmn.io
# 2	theadex.com
# 2	stylitics.com
# 2	sephora.fr
# 2	roeye.com
# 2	revcontent.com
# 2	retargetly.com
# 2	readpeak.com
# 2	rakuten.com
# 2	pxf.io
# 2	prmutv.co
# 2	primis.tech
# 2	podigee.io
# 2	pangle-ads.com
# 2	opera.com
# 2	nsaudience.pl
# 2	netid.de
# 2	mycleverpush.com
# 2	minutemedia-prebid.com
# 2	mgid.com
# 2	mfadsrvr.com
# 2	metadsp.co.uk
# 2	mediawallahscript.com
# 2	kargo.com
# 2	jwplayer.com
# 2	inforsea.com
# 2	imdb.com
# 2	hotjar.com
# 2	engagently.com
# 2	disqus.com
# 2	de17a.com
# 2	datadoghq-browser-agent.com
# 2	ctnsnet.com
# 2	congstar.de
# 2	co.in
# 2	clmbtech.com
# 2	ck-ie.com
# 2	cardinalcommerce.com
# 2	browser-intake-datadoghq.com
# 2	bidtheatre.com
# 2	azure-api.net
# 2	aralego.com
# 2	admixer.net
# 1	youborafds01.com
# 1	yellowblue.io
# 1	xg4ken.com
# 1	woosmap.com
# 1	webgains.team
# 1	webgains.com
# 1	visiblemeasures.com
# 1	viafoura.co
# 1	udmserve.net
# 1	tyllriedel.de
# 1	truffle.bid
# 1	thrtle.com
# 1	taptapnetworks.com
# 1	stories.com
# 1	springserve.com
# 1	speedcurve.com
# 1	sonobi.com
# 1	siege-amazon.com
# 1	sharethis.com
# 1	seadform.net
# 1	scalapay.com
# 1	rtbhouse.com
# 1	reflow.tv
# 1	openxcdn.net
# 1	onelink.me
# 1	onaudience.com
# 1	ojrq.net
# 1	office-partner.de
# 1	mrtnsvr.com
# 1	monki.com
# 1	mobfox.com
# 1	microsoft.com
# 1	mdhv.io
# 1	ltmsphrcl.net
# 1	livebuy.io
# 1	koe.digital
# 1	iprom.net
# 1	ippen-digital.de
# 1	insightexpressai.com
# 1	inmobi.com
# 1	infolinks.com
# 1	ggpht.com
# 1	gammaplatform.com
# 1	fazschule.net
# 1	eskimi.com
# 1	erne.co
# 1	emerse.com
# 1	e-planning.net
# 1	dmxleo.com
# 1	digitaleast.mobi
# 1	deinschrank.de
# 1	contentspread.net
# 1	company-target.com
# 1	com.tr
# 1	cnnx.link
# 1	clientgear.com
# 1	clickagy.com
# 1	brand-display.com
# 1	bkrtx.com
# 1	bitmovin.com
# 1	betweendigital.com
# 1	behamics.com
# 1	axelspringer.de
# 1	atwola.com
# 1	attentivemobile.com
# 1	amazon.dev
# 1	adprime.com
# 1	adnxs.net
# 1	adkernel.com
# 1	addthis.com
# 1	active-agent.com
# 1	a-mx.com

# %% [markdown]
# **Visualization**

# %%
df = pd.DataFrame(data1, columns=['Domain', 'Count'])

df_top20 = df.head(20)

df_top20.plot(kind='barh', x='Domain', y='Count', figsize=(8, 7))

plt.title('Top 20 3rd party domains with most connections')
plt.xlabel('Count')
plt.ylabel('')

plt.xticks( fontsize='medium', ha='right')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Websites with most connections to third party domains

# %%
conn = sqlite3.connect('../third_party_analysis.db')
cursor = conn.cursor()

query = 'SELECT host, COUNT(*) FROM domain_counts GROUP BY host ORDER BY COUNT(*) DESC'

cursor.execute(query)

data0 = cursor.fetchall()

print("Domain\tCount")
print("----------------------------")
for domain, count in data0:
    print(f"{count}\t{domain}")

conn.close()
# Out:
# Domain	Count
# ----------------------------
# 2756	merkur.de
# 2675	amazon.de
# 2269	telegraph.co.uk
# 2267	theguardian.com
# 2054	bild.de
# 1868	faz.net
# 1773	thehindu.com
# 1716	sephora.de
# 1646	n-tv.de
# 1610	cnn.com
# 1385	sueddeutsche.de
# 1209	depot-online.de
# 1086	samsung.com
# 855	zalando.de
# 830	zeit.de
# 586	nike.com
# 551	uniqlo.com
# 465	hm.com
# 456	saturn.de
# 266	douglas.de

# %% [markdown]
# **Visualization**

# %%
df = pd.DataFrame(data0, columns=['Host', 'Count'])

df_top20 = df.head(20)

df_top20.plot(kind='barh', x='Host', y='Count', figsize=(8, 7))

plt.title('Most Connections to 3rd party domains')
plt.xlabel('Count')
plt.ylabel('')

plt.xticks( fontsize='medium', ha='right')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Compare Requests by device type

# %%
conn = sqlite3.connect('../third_party_analysis.db')
cursor = conn.cursor()

query = 'SELECT type, COUNT(*) FROM domain_counts GROUP BY type ORDER BY COUNT(*) DESC'

cursor.execute(query)

data2 = cursor.fetchall()

print("Count\tdevice type")
print("----------------------------")
for domain, count in data2:
    print(f"{count}\t{domain}")

conn.close()
# Out:
# Count	device type
# ----------------------------
# 18733	desktop
# 9590	mobile

# %% [markdown]
# **Visualization**

# %%
df = pd.DataFrame(data2, columns=['Type', 'Count'])

df.plot(kind='bar', x='Type', y='Count', figsize=(5, 7))

plt.title('Comparison by Device Type')
plt.ylabel('Count of Connections')
plt.xticks(rotation=0)
plt.tight_layout()

plt.show()

# %% [markdown]
# ### Compare amount of request of each website

# %%
conn = sqlite3.connect('../third_party_analysis.db')
cursor = conn.cursor()

query = 'SELECT host, type, COUNT(*) FROM domain_counts GROUP BY host, type'

cursor.execute(query)
data3 = cursor.fetchall()

print("Count\tDevice Type\t\Host")
print("------------------------------------")
for host, type, count in data3:
    print(f"{count}\t{type}\t\t{host}")

conn.close()
# Out:
# Count	Device Type	\Host
# ------------------------------------
# 2576	desktop		amazon.de
# 99	mobile		amazon.de
# 1477	desktop		bild.de
# 577	mobile		bild.de
# 628	desktop		cnn.com
# 982	mobile		cnn.com
# 839	desktop		depot-online.de
# 370	mobile		depot-online.de
# 41	desktop		douglas.de
# 225	mobile		douglas.de
# 1335	desktop		faz.net
# 533	mobile		faz.net
# 306	desktop		hm.com
# 159	mobile		hm.com
# 1672	desktop		merkur.de
# 1084	mobile		merkur.de
# 722	desktop		n-tv.de
# 924	mobile		n-tv.de
# 502	desktop		nike.com
# 84	mobile		nike.com
# 982	desktop		samsung.com
# 104	mobile		samsung.com
# 139	desktop		saturn.de
# 317	mobile		saturn.de
# 1594	desktop		sephora.de
# 122	mobile		sephora.de
# 832	desktop		sueddeutsche.de
# 553	mobile		sueddeutsche.de
# 896	desktop		telegraph.co.uk
# 1373	mobile		telegraph.co.uk
# 1688	desktop		theguardian.com
# 579	mobile		theguardian.com
# 954	desktop		thehindu.com
# 819	mobile		thehindu.com
# 391	desktop		uniqlo.com
# 160	mobile		uniqlo.com
# 727	desktop		zalando.de
# 128	mobile		zalando.de
# 432	desktop		zeit.de
# 398	mobile		zeit.de

# %% [markdown]
# **Visualization**

# %%
df = pd.DataFrame(data3, columns=['Host', 'Device Type', 'Count'])

pivot_df = df.pivot(index='Host', columns='Device Type', values='Count').fillna(0)

pivot_df = pivot_df.sort_values('desktop', ascending=False)

ax = pivot_df.plot(kind='barh', figsize=(9, 9))

plt.title('Count of Third-Party Connections by Host and Device Type')
plt.xlabel('Count of Connections')
plt.ylabel('')
plt.legend(title='Device Type')

y_labels = ax.get_yticklabels()

for i, row in pivot_df.iterrows():
    if row.get('mobile', 0) > row.get('desktop', 0):
        y_labels[pivot_df.index.get_loc(i)].set_color('red')

ax.set_yticklabels(y_labels)

plt.show()
